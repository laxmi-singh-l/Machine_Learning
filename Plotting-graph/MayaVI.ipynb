# %% [markdown]
# <h1> MayaVI</h1>

# %% [markdown]
# MayaVI is a 3D visualization tool for scientific data. It uses the Visualization Tool Kit or VTK under the hood. Using
# the power of VTK, MayaVI is capable of producing a variety of 3-Dimensional plots and figures. It is available as a
# separate software application and also as a library. Similar to Matplotlib, this library provides an object oriented
# programming language interface to create plots without having to know about VTK.

# %%
pip install mayavi
# Out:
# Collecting mayavi
#   Downloading mayavi-4.8.3.tar.gz (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 47.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting apptools (from mayavi)
#   Downloading apptools-5.3.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting configobj (from mayavi)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting envisage (from mayavi)
#   Downloading envisage-7.0.4-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mayavi) (2.0.2)
# Collecting pyface>=6.1.1 (from mayavi)
#   Downloading pyface-8.0.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from mayavi) (2.19.2)
# Collecting traits>=6.0.0 (from mayavi)
#   Downloading traits-7.1.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (4.8 kB)
# Collecting traitsui>=7.0.0 (from mayavi)
#   Downloading traitsui-8.0.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mayavi) (25.0)
# Collecting vtk (from mayavi)
#   Using cached vtk-9.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.6 kB)
# Collecting puremagic (from mayavi)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from envisage->mayavi) (75.2.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from vtk->mayavi) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk->mayavi) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk->mayavi) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk->mayavi) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk->mayavi) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk->mayavi) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk->mayavi) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk->mayavi) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->vtk->mayavi) (1.17.0)
# Downloading pyface-8.0.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.6 MB/s eta 0:00:00
# Downloading traits-7.1.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 44.7 MB/s eta 0:00:00
# Downloading traitsui-8.0.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 38.6 MB/s eta 0:00:00
# Downloading apptools-5.3.1-py3-none-any.whl (230 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.1/230.1 kB 12.6 MB/s eta 0:00:00
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Downloading envisage-7.0.4-py3-none-any.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.0/270.0 kB 13.2 MB/s eta 0:00:00
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.1 MB/s eta 0:00:00
# Using cached vtk-9.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (112.3 MB)
# Building wheels for collected packages: mayavi
#   Building wheel for mayavi (pyproject.toml) ... done
#   Created wheel for mayavi: filename=mayavi-4.8.3-cp312-cp312-linux_x86_64.whl size=19568796 sha256=c503e74cb34c86c512d8e8abc828c02760fbb6f4fd7d4ffeef56a59a036a7176
#   Stored in directory: /root/.cache/pip/wheels/14/f5/ee/dfed85e4c517b003b5b67c161378a1b5d1baa9f176749c7b6f
# Successfully built mayavi
# Installing collected packages: puremagic, traits, configobj, pyface, apptools, vtk, traitsui, envisage, mayavi
# Successfully installed apptools-5.3.1 configobj-5.0.9 envisage-7.0.4 mayavi-4.8.3 puremagic-1.30 pyface-8.0.0 traits-7.1.0 traitsui-8.0.0 vtk-9.5.2

# %%
import numpy as np
import mayavi

# %%
from numpy import sin , cos , mgrid , pi , sqrt
from mayavi import mlab

# %%
mlab.figure(fgcolor = (0,0, 0), bgcolor = (1,1,1))
u, v = mgrid[-0.035:pi:0.01, - 0.035:pi:0.01]

x=2/3. *(cos(u) * cos(2 *v) + sqrt(2)* sin(u) * cos(v)) * cos(u) / (sqrt(2)- sin(2 * u) * sin(3 * v))

Y = 2 / 3. * (cos(u) * sin(2 * v) -
 sqrt(2) * sin(u) * sin(v)) * cos(u) / (sqrt(2)
 - sin(2 * u) * sin(3 * v))


Z = -sqrt(2) * cos(u) * cos(u) / (sqrt(2) - sin(2 * u) * sin(3 * v))

S = sin(u)
mlab.mesh(X, Y, Z, scalars=S, colormap='YlGnBu', )
# Nice view from the front
mlab.view(.0, - 5.0, 4)
mlab.show()
