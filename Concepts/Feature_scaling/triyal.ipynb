53,Female,Excellent,PG,Yes
"""

data = pd.read_csv(StringIO(csv_text))
data.head()
# Out:
#    age  gender     review education purchased
# 0   56    Male       Good        UG       Yes
# 1   46  Female    Average        PG        No
# 2   32  Female  Excellent        UG       Yes
# 3   25  Female       Poor    School        No
# 4   38  Female       Good        UG       Yes

# %%
df = data.copy()

# %%
df.head(34)
# Out:
#        review education purchased
# 0        Good        UG       Yes
# 1     Average        PG        No
# 2   Excellent        UG       Yes
# 3        Poor    School        No
# 4        Good        UG       Yes
# 5        Good       PhD        No
# 6     Average    School       Yes
# 7        Good        PG        No
# 8   Excellent        UG       Yes
# 9        Poor    School        No
# 10    Average        PG       Yes
# 11  Excellent       PhD        No
# 12    Average        UG       Yes
# 13  Excellent        UG        No
# 14       Good    School       Yes
# 15       Good        UG        No
# 16    Average        PG       Yes
# 17       Poor    School        No
# 18       Good       PhD       Yes
# 19  Excellent        UG        No
# 20    Average    School       Yes
# 21       Good        UG        No
# 22       Good        PG       Yes
# 23       Poor    School        No
# 24  Excellent        UG       Yes
# 25    Average       PhD        No
# ...

# %% [markdown]
# Here we are going to apply `one hotencoding` in `gender` column , `ordinal encoding` in `review, education` and `label encoder` in `purchesed` column

# %% [markdown]
# ` Ordinal Encoding` -> There are more levels of orders not just 2

# %%
df1 = df[['review','education','purchased']]

# %%
df = df.iloc[:,2:]

# %%
df.head(4)
# Out:
#       review education purchased
# 0       Good        UG       Yes
# 1    Average        PG        No
# 2  Excellent        UG       Yes
# 3       Poor    School        No

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,0:2] , df.iloc[:, -1], test_size= 0.2)

# %%
x_test
# Out:
#        review education
# 4        Good        UG
# 68    Average        UG
# 16    Average        PG
# 44       Poor        UG
# 21       Good        UG
# 80       Poor    School
# 12    Average        UG
# 57    Average    School
# 81  Excellent        UG
# 41  Excellent        UG
# 34       Good        PG
# 26       Good        UG
# 25    Average       PhD
# 77       Good    School
# 43    Average    School
# 7        Good        PG
# 6     Average    School
# 10    Average        PG
# 65       Poor        UG
# 33       Poor    School

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
 oe = OrdinalEncoder(categories=[['Poor','Average','Good','Excellent'],['School','UG','PG','PhD']])

# %%
oe.fit(x_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good', 'Excellent'],
#                            ['School', 'UG', 'PG', 'PhD']])

# %%
x_train = oe.transform(x_train)
x_test = oe.transform(x_test)

# %%
x_test
# Out:
# array([[2., 1.],
#        [1., 1.],
#        [1., 2.],
#        [0., 1.],
#        [2., 1.],
#        [0., 0.],
#        [1., 1.],
#        [1., 0.],
#        [3., 1.],
#        [3., 1.],
#        [2., 2.],
#        [2., 1.],
#        [1., 3.],
#        [2., 0.],
#        [1., 0.],
#        [2., 2.],
#        [1., 0.],
#        [1., 2.],
#        [0., 1.],
#        [0., 0.]])

# %%
oe.categories_
# Out:
# [array(['Poor', 'Average', 'Good', 'Excellent'], dtype=object),
#  array(['School', 'UG', 'PG', 'PhD'], dtype=object)]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() # only apply on output column

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
y_test
# Out:
# array([1, 1, 1, 1, 0, 1, 1, 0, 0, 0, 1, 1, 0, 0, 0, 0, 1, 1, 0, 0])

# %%
from google.colab import files
files.download('triyal.ipynb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-250/1849504317.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download('triyal.ipynb')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: triyal.ipynb
